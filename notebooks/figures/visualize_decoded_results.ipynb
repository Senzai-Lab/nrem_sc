# %%
from nrem_sc.constants import PROCESSED_DATA_PATH
from pathlib import Path

import re
import numpy as np
import pynapple as nap
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

DATA_PATH = Path("D:\\common_datasets\\nrem_sc")
UNITS = ['83b', '85b', '116b', '119b']

def load_decoded(save_dir):
    # Sort files by ending interval time in parent folder 
    paths = sorted(save_dir.rglob("*/position.npz"), key=lambda p: int(re.findall(r'\d+', p.parent.stem)[-2]))
    # Load and concatenate dataframes
    position_dfs = []
    state_dfs = []
    for p in paths:        
        print(f"Loading :{p}")
        position_dfs.append(nap.load_file(p).as_dataframe())
        state_dfs.append(nap.load_file(p.parent / "states.npz").as_dataframe())
    pd.concat(position_dfs), pd.concat()

# %%
unit_path = DATA_PATH / UNITS[0]
pos, states = load_decoded(unit_path)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[30], line 2
#       1 unit_path = DATA_PATH / UNITS[0]
# ----> 2 pos, states = load_decoded(unit_path)
#
# Cell In[29], line 23, in load_decoded(save_dir)
#      21     position_dfs.append(nap.load_file(p).as_dataframe())
#      22     state_dfs.append(nap.load_file(p.parent / "states.npz").as_dataframe())
# ---> 23 pd.concat(position_dfs), pd.concat()
#
# File c:\Users\iii9781\nrem_sc\.venv\Lib\site-packages\pandas\core\reshape\concat.py:395, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     380     copy = False
#     382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#    (...)    392     sort=sort,
#     393 )
# --> 395 return op.get_result()
#
# File c:\Users\iii9781\nrem_sc\.venv\Lib\site-packages\pandas\core\reshape\concat.py:684, in _Concatenator.get_result(self)
#     680             indexers[ax] = obj_labels.get_indexer(new_labels)
#     682     mgrs_indexers.append((obj._mgr, indexers))
# --> 684 new_data = concatenate_managers(
#     685     mgrs_indexers, self.new_axes, concat_axis=self.bm_axis, copy=self.copy
#     686 )
#     687 if not self.copy and not using_copy_on_write():
#     688     new_data._consolidate_inplace()
#
# File c:\Users\iii9781\nrem_sc\.venv\Lib\site-packages\pandas\core\internals\concat.py:146, in concatenate_managers(mgrs_indexers, axes, concat_axis, copy)
#     139         if (
#     140             all(_is_homogeneous_mgr(mgr, first_dtype) for mgr, _ in mgrs_indexers)
#     141             and len(mgrs_indexers) > 1
#     142         ):
#     143             # Fastpath!
#     144             # Length restriction is just to avoid having to worry about 'copy'
#     145             shape = tuple(len(x) for x in axes)
# --> 146             nb = _concat_homogeneous_fastpath(mgrs_indexers, shape, first_dtype)
#     147             return BlockManager((nb,), axes)
#     149 mgrs = _maybe_reindex_columns_na_proxy(axes, mgrs_indexers, needs_copy)
#
# File c:\Users\iii9781\nrem_sc\.venv\Lib\site-packages\pandas\core\internals\concat.py:262, in _concat_homogeneous_fastpath(mgrs_indexers, shape, first_dtype)
#     259 if all(not indexers for _, indexers in mgrs_indexers):
#     260     # https://github.com/pandas-dev/pandas/pull/52685#issuecomment-1523287739
#     261     arrs = [mgr.blocks[0].values.T for mgr, _ in mgrs_indexers]
# --> 262     arr = np.concatenate(arrs).T
#     263     bp = libinternals.BlockPlacement(slice(shape[0]))
#     264     nb = new_block_2d(arr, bp)
#
# MemoryError: Unable to allocate 60.0 GiB for an array with shape (22355280, 360) and data type float64
