# %%
from nrem_sc.constants import PROCESSED_DATA_PATH
from nrem_sc.utils import circ_bin_average

import numpy as np
import pynapple as nap
unit_id = "116b"

sleep_states = nap.load_file(PROCESSED_DATA_PATH / unit_id / "sleep.npz")
sleep_states
# Out:
# index    start    end           state
# 0        0.0      5064.999999   wake
# 1        5065.0   5351.999999   nrem
# 2        5352.0   5374.999999   wake
# 3        5375.0   5393.999999   nrem
# 4        5394.0   5403.999999   wake
# 5        5404.0   5409.999999   nrem
# 6        5410.0   5420.999999   wake
# ...      ...      ...           ...
# 455      61741.0  61750.999999  wake
# 456      61751.0  61783.999999  nrem
# 457      61784.0  61895.999999  rem
# 458      61896.0  61904.999999  wake
# 459      61905.0  61945.999999  nrem
# 460      61946.0  61968.999999  rem
# 461      61969.0  63442.0       wake
# shape: (462, 2), time unit: sec.
