# %%
import pandas as pd
import pynapple as nap

from sklearn.preprocessing import StandardScaler
from trajectoryViewer import TrajectoryViewer
from manifold_viewer_3d_fps import TrajectoryViewer3D

fname = r"R:\Basic_Sciences\Phys\SenzaiLab\Tuguldur\points_3d.csv"
data = pd.read_csv(fname, skiprows=7)
t = data['Time (Seconds)'].to_numpy()
xyz = data[['X.1', 'Y.1', 'Z.1']].to_numpy()
xyz
# Out:
# array([[  18.961712,  222.990341,  597.463928],
#        [  18.793619,  223.090088,  597.518005],
#        [  18.634874,  223.177597,  597.548584],
#        ...,
#        [ -95.047859, -133.776672,  605.645447],
#        [ -94.985588, -133.776489,  605.612305],
#        [ -94.967049, -133.765808,  605.580078]], shape=(224056, 3))

# %%
def minmax(arr):
    return (arr-arr.min())/(arr.max() - arr.min())

xyz[:,0] = minmax(xyz[:,0])
xyz[:,1] = minmax(xyz[:,1])
xyz[:,2] = minmax(xyz[:,2])

# %%
tsdf = nap.TsdFrame(t=t, d=xyz, columns=['x','y','z'])

# %%
import pygfx as gfx

grid = gfx.Grid(
    None,
    gfx.GridMaterial(
        major_step=100,
        minor_step=10,
        thickness_space="world",
        major_thickness=1,
        minor_thickness=0.1,
        infinite=True,
    ),
    orientation="xy",
)
grid.local.y = -10

# %%
v = TrajectoryViewer3D()
v.scene.add(grid)
v.add_trajectory(data=tsdf, trail_length=100)
# Out:
# Playing at frame 0
# Paused at frame 40
# Playing at frame 40

# %%
v = TrajectoryViewer(background="#ebe2e2")
v.scene.add(grid)
v.add_trajectory(data=tsdf, trail_length=100)
# Out:
# Playing at frame 0 (speed: 1.0x)
# Speed: 2.0x
# Speed: 4.0x
# Speed: 8.0x
# Speed: 16.0x
# Speed: 32.0x
# Speed: 64.0x
# Speed: 64x
# Speed: 64x
# Speed: 32.0x
# Speed: 16.0x
# Speed: 8.0x
# Speed: 4.0x
# Speed: 8.0x
# Speed: 4.0x
# Speed: 2.0x
